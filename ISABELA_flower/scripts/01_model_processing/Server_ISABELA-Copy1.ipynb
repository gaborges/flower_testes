# %%
from typing import Any, Callable, Dict, List, Optional, Tuple, Union

import flwr as fl
import tensorflow as tf

import pandas as pd

from flwr.common.logger import log
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.common import (
    EvaluateIns,
    EvaluateRes,
    FitIns,
    FitRes,
    MetricsAggregationFn,
    NDArrays,
    Parameters,
    Scalar,
    ndarrays_to_parameters,
    parameters_to_ndarrays,
)
# Out:
# 2023-07-26 19:34:17.161241: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-26 19:34:17.542021: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-07-26 19:34:18.424426: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-07-26 19:34:18.424507: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-07-26 19:34:18.424513: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
inputFolders = "../data_2019_processed/"
# selected features
inputFeatures = ["activity","location","day_of_week","light","phone_lock","proximity","sound","time_to_next_alarm", "minutes_day"]
outputClasses = ["awake","asleep"]

# %%
def loadTestData(dataSet):
    print(len(dataSet), "datasets")
    for i in range(0,len(dataSet)):
        print(i , "-", dataSet[i])
        #print(trainingDataSet[i])
        if(i == 0):
            X_test = pd.read_csv(inputFolders+"student_"+dataSet[i]+"_transformed.csv")
        else:
            dataset = pd.read_csv(inputFolders+"student_"+dataSet[i]+"_transformed.csv")
            X_test = pd.concat([X_test, dataset])
    # return the dataset        
    return X_test

# one-hot encoding function
def transform_output_nominal_class_into_one_hot_encoding(dataset):
    # create two classes based on the single class
    one_hot_encoded_data = pd.get_dummies(dataset['class'])
    #print(one_hot_encoded_data)
    dataset['awake'] = one_hot_encoded_data['awake']
    dataset['asleep'] = one_hot_encoded_data['asleep']
    
    return dataset

# one-hot encoding function
def transform_output_numerical_class_into_one_hot_encoding(dataset):
    # create two classes based on the single class
    one_hot_encoded_data = pd.get_dummies(dataset['class'])
    #print(one_hot_encoded_data)
    dataset['awake'] = one_hot_encoded_data[0]
    dataset['asleep'] = one_hot_encoded_data[1]
    
    return dataset

def transform_data_type(dataframe):
    
    # transform inputs
    for column in inputFeatures:
        dataframe[column] = dataframe[column].astype('float32')
    
    # transform outputs
    for column in outputClasses:
        dataframe[column] = dataframe[column].astype('float32')
    
    return dataframe

# %%
class SaveModelStrategy(fl.server.strategy.FedAvg):
    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[fl.server.client_proxy.ClientProxy, fl.common.FitRes]],
        failures: List[Union[Tuple[ClientProxy, FitRes], BaseException]],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:

        # Call aggregate_fit from base class (FedAvg) to aggregate parameters and metrics
        aggregated_parameters, aggregated_metrics = super().aggregate_fit(server_round, results, failures)

        if aggregated_parameters is not None:
            # Convert `Parameters` to `List[np.ndarray]`
            aggregated_ndarrays: List[np.ndarray] = fl.common.parameters_to_ndarrays(aggregated_parameters)

            # Save aggregated_ndarrays
            print(f"Saving round {server_round} aggregated_ndarrays...")
            np.savez(f"round-{server_round}-weights.npz", *aggregated_ndarrays)

        return aggregated_parameters, aggregated_metrics

# %%
def fit_config(server_round: int):
    """Return training configuration dict for each round.

    Keep batch size fixed at 32, perform two rounds of training with one
    local epoch, increase to two local epochs afterwards.
    """
    print("onn fit")
    config = {
        "batch_size": 32,
        "local_epochs": 1,
    }
    return config
	
	
def get_evaluate_fn(model):
    """Return an evaluation function for server-side evaluation."""
    
    testFolders =  [#'0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs',
                #'0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA', 
                #'2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0', 
                #'2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys', 
                #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
                #'7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA', 
                #'a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4', 
                #'ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc', 
                #'Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U', 
                #'CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA', 
                #'DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc', 
                #'DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA', # does not have asleep data
                #'dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY', 
                #'HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo', 
                #'jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw', 
                #'JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I', 
                #'K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8', 
                #'oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q', 
                #'pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM', 
                'PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc', # does not have asleep data
                #'QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ', 
                'rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw', 
                'RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI', 
                #'SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4'] 
                'VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is', 
                'Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw', 
                'XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA', 
                'YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw', 
                'ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM', 
                'ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']
    
    # load data
    X_test = loadTestData(testFolders)
    # transform output to one_hot_encoding for the testing dataset
    X_test = transform_output_nominal_class_into_one_hot_encoding(X_test)
    # transforms the data
    X_test = transform_data_type(X_test)
    # selects the data to train and test
    X_test_data = X_test[inputFeatures]
    y_test_label = X_test[outputClasses]
 
    # The `evaluate` function will be called after every round
    def evaluate(
        server_round: int, parameters: NDArrays, config: Dict[str, Scalar]
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        model.set_weights(parameters)  # Update model with the latest parameters
        loss, accuracy = model.evaluate(X_test_data, y_test_label)
        print("Testa aquiiiiiiiiiiiiiiiiiiiiiiii", loss, accuracy)
        return loss, {"accuracy": accuracy}

    return evaluate
	
def evaluate_config(server_round: int):
    """Return evaluation configuration dict for each round.
    Perform five local evaluation steps on each client (i.e., use five
    batches) during rounds, one to three, then increase to ten local
    evaluation steps.
    """
    val_steps = 5 if server_round < 4 else 10
    return {"val_steps": val_steps}

# %%
def create_keras_model():
    return tf.keras.models.Sequential([
      tf.keras.layers.InputLayer(input_shape=(9,)),
      #tf.keras.layers.Dense(9, activation=tf.keras.activations.relu), 
      tf.keras.layers.Dense(16, activation=tf.keras.activations.relu),
      tf.keras.layers.Dense(8, activation=tf.keras.activations.relu),
      tf.keras.layers.Dense(2, activation=tf.keras.activations.softmax)
      #tf.keras.layers.Dense(2, activation=tf.nn.sigmoid)
    ])
# Load model and data (MobileNetV2, CIFAR-10)
model = create_keras_model()
model.compile("adam", "sparse_categorical_crossentropy", metrics=["accuracy"])
# Out:
# 2023-07-26 19:34:20.379868: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-26 19:34:20.450542: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-07-26 19:34:20.450562: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-07-26 19:34:20.451453: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Create strategy and run server
strategy = SaveModelStrategy( 
    # (same arguments as FedAvg here) // https://github.com/adap/flower/blob/main/examples/android/server.py
        fraction_fit=1.0,
        fraction_evaluate=1.0,
        min_fit_clients=19,
        min_evaluate_clients=19,
        min_available_clients=19,        
        evaluate_fn=get_evaluate_fn(model), # evaluate_fn=None,
        on_fit_config_fn=fit_config,
        on_evaluate_config_fn=evaluate_config,
        initial_parameters=None,
)
# Out:
# 9 datasets
# 0 - PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# 1 - rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# 2 - RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# 3 - VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# 4 - Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# 5 - XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# 6 - YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# 7 - ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# 8 - ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY

# %%
# Start Flower server
fl.server.start_server(
    server_address="0.0.0.0:8099",
    config=fl.server.ServerConfig(num_rounds=30),
)
# Out:
# INFO flwr 2023-07-26 19:34:20,968 | app.py:148 | Starting Flower server, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2023-07-26 19:34:21,053 | app.py:168 | Flower ECE: gRPC server running (30 rounds), SSL is disabled
# INFO flwr 2023-07-26 19:34:21,054 | server.py:86 | Initializing global parameters
# INFO flwr 2023-07-26 19:34:21,054 | server.py:273 | Requesting initial parameters from one random client
# INFO flwr 2023-07-26 19:34:43,030 | server.py:277 | Received initial parameters from one random client
# INFO flwr 2023-07-26 19:34:43,033 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-07-26 19:34:43,034 | server.py:101 | FL starting
# DEBUG flwr 2023-07-26 19:34:43,047 | server.py:218 | fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-07-26 19:34:48,821 | server.py:232 | fit_round 1 received 2 results and 0 failures
# WARNING flwr 2023-07-26 19:34:48,824 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-07-26 19:34:48,824 | server.py:168 | evaluate_round 1: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:35:14,562 | server.py:182 | evaluate_round 1 received 19 results and 0 failures
# WARNING flwr 2023-07-26 19:35:14,563 | fedavg.py:274 | No evaluate_metrics_aggregation_fn provided
# DEBUG flwr 2023-07-26 19:35:14,564 | server.py:218 | fit_round 2: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:35:39,255 | server.py:232 | fit_round 2 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:35:39,318 | server.py:168 | evaluate_round 2: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:36:00,064 | server.py:182 | evaluate_round 2 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:36:00,065 | server.py:218 | fit_round 3: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:36:23,956 | server.py:232 | fit_round 3 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:36:23,966 | server.py:168 | evaluate_round 3: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:36:44,615 | server.py:182 | evaluate_round 3 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:36:44,616 | server.py:218 | fit_round 4: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:37:08,643 | server.py:232 | fit_round 4 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:37:08,652 | server.py:168 | evaluate_round 4: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:37:33,330 | server.py:182 | evaluate_round 4 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:37:33,331 | server.py:218 | fit_round 5: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:37:57,184 | server.py:232 | fit_round 5 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:37:57,192 | server.py:168 | evaluate_round 5: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:38:11,950 | server.py:182 | evaluate_round 5 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:38:11,951 | server.py:218 | fit_round 6: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:38:35,915 | server.py:232 | fit_round 6 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:38:35,937 | server.py:168 | evaluate_round 6: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:38:50,839 | server.py:182 | evaluate_round 6 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:38:50,840 | server.py:218 | fit_round 7: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:39:14,828 | server.py:232 | fit_round 7 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:39:14,837 | server.py:168 | evaluate_round 7: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:39:29,468 | server.py:182 | evaluate_round 7 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:39:29,469 | server.py:218 | fit_round 8: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:39:53,237 | server.py:232 | fit_round 8 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:39:53,257 | server.py:168 | evaluate_round 8: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:40:07,880 | server.py:182 | evaluate_round 8 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:40:07,881 | server.py:218 | fit_round 9: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:40:31,820 | server.py:232 | fit_round 9 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:40:31,838 | server.py:168 | evaluate_round 9: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:40:57,920 | server.py:182 | evaluate_round 9 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:40:57,927 | server.py:218 | fit_round 10: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:41:22,022 | server.py:232 | fit_round 10 received 19 results and 0 failures
# DEBUG flwr 2023-07-26 19:41:22,034 | server.py:168 | evaluate_round 10: strategy sampled 19 clients (out of 19)
# DEBUG flwr 2023-07-26 19:41:44,893 | server.py:182 | evaluate_round 10 received 18 results and 1 failures
# DEBUG flwr 2023-07-26 19:41:44,903 | server.py:218 | fit_round 11: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:42:08,899 | server.py:232 | fit_round 11 received 18 results and 0 failures
# DEBUG flwr 2023-07-26 19:42:08,908 | server.py:168 | evaluate_round 11: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:42:29,613 | server.py:182 | evaluate_round 11 received 18 results and 0 failures
# DEBUG flwr 2023-07-26 19:42:29,613 | server.py:218 | fit_round 12: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:42:51,288 | server.py:232 | fit_round 12 received 18 results and 0 failures
# DEBUG flwr 2023-07-26 19:42:51,296 | server.py:168 | evaluate_round 12: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:43:05,868 | server.py:182 | evaluate_round 12 received 18 results and 0 failures
# DEBUG flwr 2023-07-26 19:43:05,869 | server.py:218 | fit_round 13: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:46:31,442 | server.py:232 | fit_round 13 received 18 results and 0 failures
# DEBUG flwr 2023-07-26 19:46:31,461 | server.py:168 | evaluate_round 13: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:47:14,884 | server.py:182 | evaluate_round 13 received 18 results and 0 failures
# DEBUG flwr 2023-07-26 19:47:14,902 | server.py:218 | fit_round 14: strategy sampled 18 clients (out of 18)
# DEBUG flwr 2023-07-26 19:47:36,594 | server.py:232 | fit_round 14 received 17 results and 1 failures
# DEBUG flwr 2023-07-26 19:47:36,612 | server.py:168 | evaluate_round 14: strategy sampled 17 clients (out of 17)
# DEBUG flwr 2023-07-26 19:47:47,020 | server.py:182 | evaluate_round 14 received 17 results and 0 failures
# DEBUG flwr 2023-07-26 19:47:47,021 | server.py:218 | fit_round 15: strategy sampled 17 clients (out of 17)
# DEBUG flwr 2023-07-26 19:48:00,842 | server.py:232 | fit_round 15 received 17 results and 0 failures
# DEBUG flwr 2023-07-26 19:48:00,847 | server.py:168 | evaluate_round 15: strategy sampled 17 clients (out of 17)
# DEBUG flwr 2023-07-26 19:48:11,285 | server.py:182 | evaluate_round 15 received 17 results and 0 failures
# DEBUG flwr 2023-07-26 19:48:11,286 | server.py:218 | fit_round 16: strategy sampled 17 clients (out of 17)
# DEBUG flwr 2023-07-26 19:48:25,099 | server.py:232 | fit_round 16 received 17 results and 0 failures
# DEBUG flwr 2023-07-26 19:48:25,111 | server.py:168 | evaluate_round 16: strategy sampled 17 clients (out of 17)
# DEBUG flwr 2023-07-26 19:48:35,526 | server.py:182 | evaluate_round 16 received 17 results and 0 failures
# DEBUG flwr 2023-07-26 19:48:35,527 | server.py:218 | fit_round 17: strategy sampled 17 clients (out of 17)
# DEBUG flwr 2023-07-26 19:55:00,283 | server.py:232 | fit_round 17 received 16 results and 1 failures
# DEBUG flwr 2023-07-26 19:55:00,297 | server.py:168 | evaluate_round 17: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:55:10,773 | server.py:182 | evaluate_round 17 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:55:10,774 | server.py:218 | fit_round 18: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:55:24,236 | server.py:232 | fit_round 18 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:55:24,243 | server.py:168 | evaluate_round 18: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:55:34,630 | server.py:182 | evaluate_round 18 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:55:34,631 | server.py:218 | fit_round 19: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:55:48,235 | server.py:232 | fit_round 19 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:55:48,243 | server.py:168 | evaluate_round 19: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:56:00,442 | server.py:182 | evaluate_round 19 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:56:00,444 | server.py:218 | fit_round 20: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:56:13,982 | server.py:232 | fit_round 20 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:56:13,991 | server.py:168 | evaluate_round 20: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:56:24,406 | server.py:182 | evaluate_round 20 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:56:24,416 | server.py:218 | fit_round 21: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:56:37,996 | server.py:232 | fit_round 21 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:56:38,004 | server.py:168 | evaluate_round 21: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:56:48,412 | server.py:182 | evaluate_round 21 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:56:48,413 | server.py:218 | fit_round 22: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:57:01,964 | server.py:232 | fit_round 22 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:57:01,972 | server.py:168 | evaluate_round 22: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:57:12,370 | server.py:182 | evaluate_round 22 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:57:12,370 | server.py:218 | fit_round 23: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:57:25,919 | server.py:232 | fit_round 23 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:57:25,926 | server.py:168 | evaluate_round 23: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:57:36,328 | server.py:182 | evaluate_round 23 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:57:36,329 | server.py:218 | fit_round 24: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:57:49,915 | server.py:232 | fit_round 24 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:57:49,931 | server.py:168 | evaluate_round 24: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:58:00,354 | server.py:182 | evaluate_round 24 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:58:00,355 | server.py:218 | fit_round 25: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:58:13,879 | server.py:232 | fit_round 25 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:58:13,895 | server.py:168 | evaluate_round 25: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:58:24,442 | server.py:182 | evaluate_round 25 received 16 results and 0 failures
# DEBUG flwr 2023-07-26 19:58:24,453 | server.py:218 | fit_round 26: strategy sampled 16 clients (out of 16)
# DEBUG flwr 2023-07-26 19:58:48,207 | server.py:232 | fit_round 26 received 15 results and 1 failures
# DEBUG flwr 2023-07-26 19:58:48,223 | server.py:168 | evaluate_round 26: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 19:58:58,713 | server.py:182 | evaluate_round 26 received 15 results and 0 failures
# DEBUG flwr 2023-07-26 19:58:58,714 | server.py:218 | fit_round 27: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 19:59:11,298 | server.py:232 | fit_round 27 received 15 results and 0 failures
# DEBUG flwr 2023-07-26 19:59:11,305 | server.py:168 | evaluate_round 27: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 19:59:21,715 | server.py:182 | evaluate_round 27 received 15 results and 0 failures
# DEBUG flwr 2023-07-26 19:59:21,716 | server.py:218 | fit_round 28: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 19:59:35,216 | server.py:232 | fit_round 28 received 15 results and 0 failures
# DEBUG flwr 2023-07-26 19:59:35,223 | server.py:168 | evaluate_round 28: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 19:59:45,633 | server.py:182 | evaluate_round 28 received 15 results and 0 failures
# DEBUG flwr 2023-07-26 19:59:45,634 | server.py:218 | fit_round 29: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 19:59:58,340 | server.py:232 | fit_round 29 received 15 results and 0 failures
# DEBUG flwr 2023-07-26 19:59:58,366 | server.py:168 | evaluate_round 29: strategy sampled 15 clients (out of 15)
# DEBUG flwr 2023-07-26 20:03:18,986 | server.py:182 | evaluate_round 29 received 14 results and 1 failures
# DEBUG flwr 2023-07-26 20:03:18,997 | server.py:218 | fit_round 30: strategy sampled 14 clients (out of 14)
# DEBUG flwr 2023-07-26 20:03:32,090 | server.py:232 | fit_round 30 received 14 results and 0 failures
# DEBUG flwr 2023-07-26 20:03:32,095 | server.py:168 | evaluate_round 30: strategy sampled 14 clients (out of 14)
# DEBUG flwr 2023-07-26 20:03:42,463 | server.py:182 | evaluate_round 30 received 14 results and 0 failures
# INFO flwr 2023-07-26 20:03:42,480 | server.py:147 | FL finished in 1739.4333510840002
# INFO flwr 2023-07-26 20:03:42,535 | app.py:218 | app_fit: losses_distributed [(1, 0.5052440762519836), (2, 0.4215170741081238), (3, 0.4159625172615051), (4, 0.4108876585960388), (5, 0.40434759855270386), (6, 0.3999510705471039), (7, 0.3951323926448822), (8, 0.39419811964035034), (9, 0.3937778174877167), (10, 0.3971949517726898), (11, 0.4056280255317688), (12, 0.40988463163375854), (13, 0.4104570150375366), (14, 0.41274717450141907), (15, 0.416326642036438), (16, 0.4171164631843567), (17, 0.4178602993488312), (18, 0.41957470774650574), (19, 0.4238024353981018), (20, 0.42411598563194275), (21, 0.42553678154945374), (22, 0.4252961277961731), (23, 0.42576488852500916), (24, 0.42567896842956543), (25, 0.4287911057472229), (26, 0.4252540171146393), (27, 0.42829734086990356), (28, 0.43093743920326233), (29, 0.42644375562667847), (30, 0.4220045208930969)]
# INFO flwr 2023-07-26 20:03:42,536 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-07-26 20:03:42,536 | app.py:220 | app_fit: metrics_distributed {}
# INFO flwr 2023-07-26 20:03:42,537 | app.py:221 | app_fit: losses_centralized []
# INFO flwr 2023-07-26 20:03:42,538 | app.py:222 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.5052440762519836
# 	round 2: 0.4215170741081238
# 	round 3: 0.4159625172615051
# 	round 4: 0.4108876585960388
# 	round 5: 0.40434759855270386
# 	round 6: 0.3999510705471039
# 	round 7: 0.3951323926448822
# 	round 8: 0.39419811964035034
# 	round 9: 0.3937778174877167
# 	round 10: 0.3971949517726898
# 	round 11: 0.4056280255317688
# 	round 12: 0.40988463163375854
# 	round 13: 0.4104570150375366
# 	round 14: 0.41274717450141907
# 	round 15: 0.416326642036438
# 	round 16: 0.4171164631843567
# 	round 17: 0.4178602993488312
# 	round 18: 0.41957470774650574
# 	round 19: 0.4238024353981018
# 	round 20: 0.42411598563194275
# 	round 21: 0.42553678154945374
# 	round 22: 0.4252961277961731
# 	round 23: 0.42576488852500916
# 	round 24: 0.42567896842956543
# 	round 25: 0.4287911057472229
# 	round 26: 0.4252540171146393
# 	round 27: 0.42829734086990356
# 	round 28: 0.43093743920326233
# 	round 29: 0.42644375562667847
# 	round 30: 0.4220045208930969
