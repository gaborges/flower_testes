# %%
import csv
import json
import pandas as pd
from datetime import datetime
import numpy as np
from os.path import exists

from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
outputFolders = "../data_2019_processed/form/"

baseInputFolder = "../../Dataset_ECUADOR_2019/"

# Dataframe of all datasets
# initialize list of lists
datasets = [['0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs'],
            ['0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA'], 
            ['2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0'], 
            ['2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys'], 
            #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
            ['7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA'], 
            ['a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4'], 
            ['ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc'], 
            ['Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U'], 
            ['CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA'], 
            ['DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc'], 
            ['DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA'], 
            ['dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY'], 
            ['HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo'], 
            ['jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw'], 
            ['JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I'], 
            ['K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8'], 
            ['oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q'], 
            ['pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM'], 
            ['PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc'], 
            ['QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ'], 
            ['rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw'], 
            ['RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI'], 
            ['SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4'], 
            ['VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is'], 
            ['Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw'], 
            ['XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA'], 
            ['YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw'], 
            ['ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM'], 
            ['ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']]
  
# Create the pandas DataFrame
folders = pd.DataFrame(datasets, columns=['folder'])

# %%
pd.read_csv("../../Dataset_ECUADOR_2019/0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs/sleep_form_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv")
# Out:
#     Unnamed: 0            sleep_time           wakeup_time  sleep  arousal  \
# 0            0  2018-05-15T05:30:29Z  2018-05-15T11:30:29Z      3        3
# 1            1  2018-05-15T17:00:00Z  2018-05-16T11:00:04Z      3        4
# 2            2  2018-05-15T17:00:00Z  2018-05-16T11:00:08Z      3        4
# 3            3  2018-05-17T04:45:00Z  2018-05-17T11:15:19Z      3        0
# 4            4  2018-05-18T03:00:00Z  2018-05-18T08:30:49Z      1        0
# 5            5  2018-05-19T05:00:53Z  2018-05-19T10:15:53Z      3        3
# 6            6  2018-05-21T06:15:52Z  2018-05-21T10:30:52Z      4        0
# 7            7  2018-05-22T04:45:00Z  2018-05-22T11:30:21Z      3        1
# 8            8  2018-05-22T04:30:00Z  2018-05-22T11:30:40Z      3        1
# 9            9  2018-05-23T15:00:09Z  2018-05-23T12:30:09Z      2        2
# 10          10  2018-05-24T04:30:00Z  2018-05-24T10:30:33Z      1        2
# 11          11  2018-05-25T04:30:00Z  2018-05-25T12:30:37Z      3        0
# 12          12  2018-05-26T06:30:12Z  2018-05-26T12:30:12Z      3        1
# 13          13  2018-05-26T06:45:29Z  2018-05-26T12:30:29Z      3        1
# 14          14  2018-05-27T18:00:56Z  2018-05-27T14:00:56Z      0        0
# 15          15  2018-05-27T10:00:16Z  2018-05-27T18:00:16Z      0        0
# 16          16  2018-05-28T06:30:08Z  2018-05-28T10:30:08Z      2        2
# 17          17  2018-05-30T06:45:35Z  2018-05-30T12:00:35Z      2        1
# 18          18  2018-05-31T07:00:27Z  2018-05-31T10:30:27Z      3        0
# 19          19  2018-06-01T07:00:56Z  2018-06-01T10:30:56Z      0        1
# 20          20  2018-06-01T16:45:00Z  2018-06-02T13:30:12Z      4        2
# 21          21  2018-06-03T07:00:00Z  2018-06-03T15:00:00Z      0        0
# 22          22  2018-06-03T04:45:00Z  2018-06-03T13:30:37Z      3        2
# 23          23  2018-06-04T05:45:42Z  2018-06-04T11:00:42Z      4        1
# 24          24  2018-06-05T14:00:12Z  2018-06-05T14:00:12Z      0        0
# 25          25  2018-06-05T04:45:00Z  2018-06-05T11:30:58Z      3        2
# 26          26  2018-06-06T06:00:16Z  2018-06-06T12:00:16Z      3        3
# 27          27  2018-06-07T04:30:00Z  2018-06-07T10:30:58Z      3        1
# 28          28  2018-06-08T05:00:35Z  2018-06-08T13:00:35Z      0        0
# 29          29  2018-06-08T04:45:00Z  2018-06-08T10:00:34Z      3        1
# 30          30  2018-06-10T06:30:11Z  2018-06-10T12:30:11Z      4        1
# 31          31  2018-06-11T05:30:45Z  2018-06-11T10:30:45Z      3        1
# 32          32  2018-06-12T08:00:34Z  2018-06-12T16:00:34Z      0        0
#
#     valence  dominance  physical_activity  sociability  study  \
# 0         3          4                  3            4      3
# 1         3          4                  3            4      2
# 2         3          4                  3            4      2
# 3         4          3                  1            2      1
# 4         1          1                  0            0      1
# 5         1          3                  2            2      4
# 6         2          0                  1            2      3
# 7         3          3                  3            2      3
# 8         3          2                  3            2      3
# 9         3          3                  1            2      2
# 10        1          2                  1            1      2
# 11        2          3                  1            1      4
# 12        3          2                  2            1      4
# 13        4          2                  1            1      4
# 14        0          0                  0            0      0
# 15        0          0                  0            0      0
# 16        3          2                  3            3      4
# 17        2          3                  1            1      3
# 18        3          0                  1            1      3
# 19        1          1                  1            0      4
# 20        4          3                  1            3      4
# 21        0          0                  0            0      0
# 22        0          1                  1            0      4
# 23        3          1                  3            3      4
# 24        0          0                  0            0      0
# 25        1          2                  2            1      3
# 26        3          3                  4            3      4
# 27        3          1                  3            2      4
# 28        0          0                  0            0      0
# 29        3          3                  1            3      4
# 30        3          2                  3            3      4
# 31        3          3                  3            3      4
# 32        0          0                  0            0      0
#
#                timestamp
# 0   2018-05-15T14:31:29Z
# 1   2018-05-16T14:07:04Z
# 2   2018-05-16T14:07:08Z
# 3   2018-05-17T14:16:19Z
# 4   2018-05-18T15:12:49Z
# 5   2018-05-19T15:51:53Z
# 6   2018-05-21T15:33:52Z
# 7   2018-05-22T13:55:21Z
# 8   2018-05-22T15:59:40Z
# 9   2018-05-23T15:44:09Z
# 10  2018-05-24T14:15:33Z
# 11  2018-05-25T15:56:37Z
# 12  2018-05-26T14:40:12Z
# 13  2018-05-26T15:48:29Z
# 14  2018-05-27T18:03:56Z
# 15  2018-05-27T18:56:16Z
# 16  2018-05-28T17:34:08Z
# 17  2018-05-30T15:56:35Z
# 18  2018-05-31T13:08:27Z
# 19  2018-06-01T16:40:56Z
# 20  2018-06-03T03:45:12Z
# 21  2018-06-03T15:06:00Z
# 22  2018-06-03T16:37:37Z
# 23  2018-06-04T15:44:42Z
# 24  2018-06-05T14:09:12Z
# 25  2018-06-05T16:02:58Z
# 26  2018-06-06T15:46:16Z
# 27  2018-06-07T16:21:58Z
# 28  2018-06-08T13:12:35Z
# 29  2018-06-08T15:52:34Z
# 30  2018-06-10T15:37:11Z
# 31  2018-06-11T13:54:45Z
# 32  2018-06-12T16:14:34Z

# %%
def isSameDayConflict(timestampA,timestampB): # limit 
    #2018-06-02T15:21:58Z
    onlyDateA =  timestampA.split("T")
    onlyDateB =  timestampB.split("T")
    tempA = datetime.strptime(onlyDateA[0],'%Y-%m-%d').timestamp()
    tempB = datetime.strptime(onlyDateB[0],'%Y-%m-%d').timestamp()
    if(tempA==tempB):
        return True
    else:
        return False

def mapDuplicatedReports(dataframe):
    # create duplicated column flag, if it not exists
    #if not ('duplicated' in dataframe.columns):
    dataframe['duplicated'] = 0
    # limit must be -1 because we compare with the next value
    limit = dataframe.shape[0] - 1
    # reset index
    dataframe = dataframe.reset_index()
    # do the analysis
    for index in range(0,limit):
        current = dataframe['wakeup_time'][index]
        #print(current)
        if current >= dataframe['sleep_time'][index+1]:
            #print(index,dataframe['sleep_time'][index],dataframe['time_sleeping_s'][index],dataframe['wakeup_time'][index],dataframe['timestamp'][index])
            #print(dataframe['timestamp'][index],dataframe['timestamp'][index+1])
            if isSameDayConflict(dataframe['timestamp'][index],dataframe['timestamp'][index+1]):
                dataframe['duplicated'][index] = 1
                dataframe['duplicated'][index+1] = 0
    return dataframe
                
print("Conflict",isSameDayConflict('2018-06-02T15:21:58Z','2018-06-02T15:21:58Z'))
print("Not conflict",isSameDayConflict('2018-06-02T15:21:58Z','2018-06-03T15:21:58Z'))
# Out:
# Conflict True
# Not conflict False

# %%
print("Evaluation: script to deal with negative sleep times")
test = []
temposDuplicadas = 0
temposMaioresDe12 = 0
temposNegativos = 0
temposTotal = 0
temposUseful = 0

for indexFolder, folder in folders.iterrows():
    #testFile = "2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv"
    
    # check f the path exists (becouse kaggle removed the + character)
    formFileName = "sleep_form_"+folder['folder']+".csv"
    if(not(exists(baseInputFolder+folder['folder']+"/"+formFileName))):
        formFileName = "sleep_form_"+folder['folder'].replace("+","")+".csv"
        
    print(formFileName)
    file = baseInputFolder+folder['folder']+"/"+formFileName
    dataset = pd.read_csv(file)
    data = dict()
    
    # test transformation
    dataframe = dataset
    # sleep_time to timestamp
    for indexFolder, content in dataframe['sleep_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['sleep_time'][indexFolder] = temp.timestamp()

    # wakeup_time to timestamp
    for indexFolder, content in dataframe['wakeup_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['wakeup_time'][indexFolder] = temp.timestamp() 
        
        # verify if the wakeup_time and sleep_time are inverted
        temp_time = dataframe['sleep_time'][indexFolder]
        if(temp_time > dataframe['wakeup_time'][indexFolder]):
            dataframe['sleep_time'][indexFolder]  = dataframe['wakeup_time'][indexFolder]
            dataframe['wakeup_time'][indexFolder] = temp_time

    # time sleeling in seconds
    dataframe['time_sleeping'] = dataframe['wakeup_time'] - dataframe['sleep_time']
    # convert time sleeping to hours
    dataframe['time_sleeping_hs'] = dataframe['time_sleeping'] /60/60
            
    # replace in 24hs of max sleeping
    #for indexFolder, content in dataframe['time_sleeping_hs'].items():
    #    if(content > 24.0):
    #        dataframe['time_sleeping'][indexFolder] = 24.0 *60 *60
    #        dataframe['time_sleeping_hs'][indexFolder] = 24.0
    #        dataframe['wakeup_time'][indexFolder] = dataframe['sleep_time'][indexFolder] + dataframe['time_sleeping'][indexFolder]
    
    # remove forms with more than then 12hs
    dfOnlyWithLess12hs = dataframe.loc[dataframe['time_sleeping_hs'] <= 24.0]
    # map forms with same day of report
    dfOnlyUnique = mapDuplicatedReports(dfOnlyWithLess12hs)
    # remove duplicates
    dfOnlyUnique = dfOnlyUnique.loc[dfOnlyUnique['duplicated'] == 0]
    # remove forms with zero hours of sleep
    dfOnlyUseful = dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] > 0.0]
   
    temposTotal = temposTotal + dataframe.shape[0]
    temposMaioresDe12 = temposMaioresDe12 + dataframe.shape[0]-dfOnlyWithLess12hs.shape[0]
    temposDuplicadas = temposDuplicadas + (dfOnlyWithLess12hs.shape[0]-dfOnlyUnique.shape[0])
    temposNegativos = temposNegativos + dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0] 
    temposUseful = temposUseful + dfOnlyUseful.shape[0]
        
    print("")
    print("")
    print("")
    print("Client: ",folder['folder'])
    print("Total count: ",dataframe.shape[0])
    print("Count with less 24hs: ",dfOnlyWithLess12hs.shape[0], " - removed: ",dataframe.shape[0]-dfOnlyWithLess12hs.shape[0])
    print("Count without duplicates: ",dfOnlyUnique.shape[0]," - removed: ",dfOnlyWithLess12hs.shape[0]-dfOnlyUnique.shape[0])
    print("Count negatives: ",dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0])
    print("Count useful: ",dfOnlyUseful.shape[0])
    #print([dataframe['time_sleeping'],dataframe['time_sleeping']])
    #test.append(data)
    
temposNormais = temposTotal - temposDuplicadas - temposMaioresDe12 - temposNegativos
print("")
print("")
print("")
print("Total:",temposTotal)    
print("duplicated:",temposDuplicadas)
print(">24:",temposMaioresDe12)
print("0-24:",temposNormais, "useful")
print("<=0:",temposNegativos)
print("Useful:",temposUseful, "useful")
# Out:
# Evaluation: script to deal with negative sleep times
# sleep_form_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv
#
#
#
# Client:  0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs
# Total count:  33
# Count with less 24hs:  33  - removed:  0
# Count without duplicates:  26  - removed:  7
# Count negatives:  0
# Count useful:  26
# sleep_form_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv
#
#
#
# Client:  0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA
# Total count:  31
# Count with less 24hs:  31  - removed:  0
# Count without duplicates:  22  - removed:  9
# Count negatives:  0
# Count useful:  22
# sleep_form_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv
#
#
#
# Client:  2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0
# Total count:  48
# Count with less 24hs:  48  - removed:  0
# Count without duplicates:  30  - removed:  18
# Count negatives:  0
# Count useful:  30
# sleep_form_2J22RukYnEbKTk7tiUVDBkorcyL5NKN6TrLe89ys.csv
#
#
#
# Client:  2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys
# Total count:  50
# Count with less 24hs:  40  - removed:  10
# Count without duplicates:  15  - removed:  25
# Count negatives:  0
# Count useful:  15
# sleep_form_7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA.csv
#
#
#
# Client:  7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA
# Total count:  15
# Count with less 24hs:  14  - removed:  1
# Count without duplicates:  13  - removed:  1
# Count negatives:  0
# Count useful:  13
# sleep_form_a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4.csv
#
#
#
# Client:  a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4
# Total count:  50
# Count with less 24hs:  27  - removed:  23
# Count without duplicates:  18  - removed:  9
# Count negatives:  0
# Count useful:  18
# sleep_form_ae4JJBZDycEcY8McJF3BxyvZ1619y03BNdCxzpZTc.csv
#
#
#
# Client:  ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc
# Total count:  22
# Count with less 24hs:  22  - removed:  0
# Count without duplicates:  18  - removed:  4
# Count negatives:  0
# Count useful:  18
# sleep_form_Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U.csv
#
#
#
# Client:  Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U
# Total count:  53
# Count with less 24hs:  45  - removed:  8
# Count without duplicates:  26  - removed:  19
# Count negatives:  0
# Count useful:  26
# sleep_form_CH8f0yZkZL13zWuE9ks1CkVJRVrrjsGdUXHrZ6YeA.csv
#
#
#
# Client:  CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA
# Total count:  66
# Count with less 24hs:  65  - removed:  1
# Count without duplicates:  28  - removed:  37
# Count negatives:  2
# Count useful:  26
# sleep_form_DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc.csv
#
#
#
# Client:  DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc
# Total count:  22
# Count with less 24hs:  22  - removed:  0
# Count without duplicates:  21  - removed:  1
# Count negatives:  0
# Count useful:  21
# sleep_form_DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA.csv
#
#
#
# Client:  DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA
# Total count:  6
# Count with less 24hs:  6  - removed:  0
# Count without duplicates:  3  - removed:  3
# Count negatives:  0
# Count useful:  3
# sleep_form_dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY.csv
#
#
#
# Client:  dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY
# Total count:  66
# Count with less 24hs:  63  - removed:  3
# Count without duplicates:  31  - removed:  32
# Count negatives:  0
# Count useful:  31
# sleep_form_HFvs2CohmhHteAaCzFasjzegGzxZKPhkrX23iI6Xo.csv
#
#
#
# Client:  HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo
# Total count:  49
# Count with less 24hs:  44  - removed:  5
# Count without duplicates:  24  - removed:  20
# Count negatives:  0
# Count useful:  24
# sleep_form_jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw.csv
#
#
#
# Client:  jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw
# Total count:  28
# Count with less 24hs:  27  - removed:  1
# Count without duplicates:  24  - removed:  3
# Count negatives:  0
# Count useful:  24
# sleep_form_JkYR7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I.csv
#
#
#
# Client:  JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I
# Total count:  52
# Count with less 24hs:  52  - removed:  0
# Count without duplicates:  30  - removed:  22
# Count negatives:  0
# Count useful:  30
# sleep_form_K4SLohfTN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8.csv
#
#
#
# Client:  K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8
# Total count:  42
# Count with less 24hs:  40  - removed:  2
# Count without duplicates:  23  - removed:  17
# Count negatives:  0
# Count useful:  23
# sleep_form_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv
#
#
#
# Client:  oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
# Total count:  50
# Count with less 24hs:  49  - removed:  1
# Count without duplicates:  38  - removed:  11
# Count negatives:  2
# Count useful:  36
# sleep_form_pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM.csv
#
#
#
# Client:  pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM
# Total count:  22
# Count with less 24hs:  20  - removed:  2
# Count without duplicates:  18  - removed:  2
# Count negatives:  0
# Count useful:  18
# sleep_form_PZCf1nfvhR6fk7sPNMYOgb8BAMmtQtfoRS83Suc.csv
#
#
#
# Client:  PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# Total count:  9
# Count with less 24hs:  8  - removed:  1
# Count without duplicates:  6  - removed:  2
# Count negatives:  0
# Count useful:  6
# sleep_form_QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXXcQ.csv
#
#
#
# Client:  QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ
# Total count:  28
# Count with less 24hs:  27  - removed:  1
# Count without duplicates:  22  - removed:  5
# Count negatives:  0
# Count useful:  22
# sleep_form_rIl2UK9bQtzpFdbJAdbBxEa5GbgrgC030yEaENLw.csv
#
#
#
# Client:  rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# Total count:  19
# Count with less 24hs:  15  - removed:  4
# Count without duplicates:  15  - removed:  0
# Count negatives:  0
# Count useful:  15
# sleep_form_RoBW3cDOO9wWRMPO2twQff83MPcOXn6gJa1DafreI.csv
#
#
#
# Client:  RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# Total count:  40
# Count with less 24hs:  39  - removed:  1
# Count without duplicates:  28  - removed:  11
# Count negatives:  0
# Count useful:  28
# sleep_form_SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4.csv
#
#
#
# Client:  SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4
# Total count:  20
# Count with less 24hs:  20  - removed:  0
# Count without duplicates:  19  - removed:  1
# Count negatives:  0
# Count useful:  19
# sleep_form_VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is.csv
#
#
#
# Client:  VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# Total count:  38
# Count with less 24hs:  32  - removed:  6
# Count without duplicates:  25  - removed:  7
# Count negatives:  0
# Count useful:  25
# sleep_form_Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw.csv
#
#
#
# Client:  Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# Total count:  24
# Count with less 24hs:  24  - removed:  0
# Count without duplicates:  16  - removed:  8
# Count negatives:  0
# Count useful:  16
# sleep_form_XCKRE0BWRHxfP1kZIihgtTjUjSp2GE8v5ZlhcIhVmA.csv
#
#
#
# Client:  XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# Total count:  35
# Count with less 24hs:  34  - removed:  1
# Count without duplicates:  26  - removed:  8
# Count negatives:  0
# Count useful:  26
# sleep_form_YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw.csv
#
#
#
# Client:  YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# Total count:  25
# Count with less 24hs:  23  - removed:  2
# Count without duplicates:  23  - removed:  0
# Count negatives:  0
# Count useful:  23
# sleep_form_ypklj8GJ15rOIH1lpKQtFJOuKVdvyCuBPqhY3aoM.csv
#
#
#
# Client:  ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# Total count:  1
# Count with less 24hs:  1  - removed:  0
# Count without duplicates:  1  - removed:  0
# Count negatives:  0
# Count useful:  1
# sleep_form_ZSsAZ0PqMCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv
#
#
#
# Client:  ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY
# Total count:  21
# Count with less 24hs:  20  - removed:  1
# Count without duplicates:  20  - removed:  0
# Count negatives:  1
# Count useful:  19
#
#
#
# Total: 965
# duplicated: 282
# >24: 74
# 0-24: 604 useful
# <=0: 5
# Useful: 604 useful

# %%
print("Generation: script to deal with negative sleep times and other issues")
test = []
temposDuplicadas = 0
temposMaioresDe12 = 0
temposNegativos = 0
temposTotal = 0
temposUseful = 0

for indexFolder, folder in folders.iterrows():
    #testFile = "2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv"
    
    # check f the path exists (becouse kaggle removed the + character)
    formFileName = "sleep_form_"+folder['folder']+".csv"
    if(not(exists(baseInputFolder+folder['folder']+"/"+formFileName))):
        formFileName = "sleep_form_"+folder['folder'].replace("+","")+".csv"
        
    print(formFileName)
    file = baseInputFolder+folder['folder']+"/"+formFileName
    dataset = pd.read_csv(file)
    data = dict()
    
    # test transformation
    dataframe = dataset
    # sleep_time to timestamp
    for indexFolder, content in dataframe['sleep_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['sleep_time'][indexFolder] = temp.timestamp()

    # wakeup_time to timestamp
    for indexFolder, content in dataframe['wakeup_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['wakeup_time'][indexFolder] = temp.timestamp() 
        
        # verify if the wakeup_time and sleep_time are inverted
        temp_time = dataframe['sleep_time'][indexFolder]
        if(temp_time > dataframe['wakeup_time'][indexFolder]):
            dataframe['sleep_time'][indexFolder]  = dataframe['wakeup_time'][indexFolder]
            dataframe['wakeup_time'][indexFolder] = temp_time

    # time sleeling in seconds
    dataframe['time_sleeping'] = dataframe['wakeup_time'] - dataframe['sleep_time']
    # convert time sleeping to hours
    dataframe['time_sleeping_hs'] = dataframe['time_sleeping'] /60/60
    
    # replace in 12hs of max sleeping
    #for indexFolder, content in dataframe['time_sleeping_hs'].items():
    #    if(content > 12.0):
    #       dataframe['time_sleeping'][indexFolder] = 24.0 *60 *60
    #       dataframe['time_sleeping_hs'][indexFolder] = 24.0
    #       dataframe['wakeup_time'][indexFolder] = dataframe['sleep_time'][indexFolder] + dataframe['time_sleeping'][indexFolder]
    
    # remove forms with more than then 25hs
    dfOnlyWithLess12hs = dataframe.loc[dataframe['time_sleeping_hs'] <= 24.0]
    # map forms with same day of report
    dfOnlyUnique = mapDuplicatedReports(dfOnlyWithLess12hs)
    # remove duplicates
    dfOnlyUnique = dfOnlyUnique.loc[dfOnlyUnique['duplicated'] == 0]
    # remove forms with zero hours of sleep
    dfOnlyUseful = dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] > 0.0]
   
    temposTotal = temposTotal + dataframe.shape[0]
    temposMaioresDe12 = temposMaioresDe12 + dataframe.shape[0]-dfOnlyWithLess12hs.shape[0]
    temposDuplicadas = temposDuplicadas + (dfOnlyWithLess12hs.shape[0]-dfOnlyUnique.shape[0])
    temposNegativos = temposNegativos + dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0] 
    temposUseful = temposUseful + dfOnlyUseful.shape[0]
    
    # write in file
    fileOutput = outputFolders+"sleep_form_"+folder['folder']+"_treated.csv"
    dfOnlyUseful.to_csv(fileOutput)
        
    print("")
    print("")
    print("")
    print("Client: ",folder['folder'])
    print("Total count: ",dataframe.shape[0])
    print("Count with less 24hs: ",dfOnlyWithLess12hs.shape[0], " - removed: ",dataframe.shape[0]-dfOnlyWithLess12hs.shape[0])
    print("Count without duplicates: ",dfOnlyUnique.shape[0]," - removed: ",dfOnlyWithLess12hs.shape[0]-dfOnlyUnique.shape[0])
    print("Count negatives: ",dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0])
    print("Count useful: ",dfOnlyUseful.shape[0])
    #print([dataframe['time_sleeping'],dataframe['time_sleeping']])
    #test.append(data)
    
temposNormais = temposTotal - temposDuplicadas - temposMaioresDe12 - temposNegativos
print("")
print("")
print("")
print("Total:",temposTotal)    
print("duplicated:",temposDuplicadas)
print(">24:",temposMaioresDe12)
print("0-24:",temposNormais, "useful")
print("<=0:",temposNegativos)
print("Useful:",temposUseful, "useful")
# Out:
# Generation: script to deal with negative sleep times and other issues
# sleep_form_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv
#
#
#
# Client:  0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs
# Total count:  33
# Count with less 24hs:  33  - removed:  0
# Count without duplicates:  26  - removed:  7
# Count negatives:  0
# Count useful:  26
# sleep_form_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv
#
#
#
# Client:  0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA
# Total count:  31
# Count with less 24hs:  31  - removed:  0
# Count without duplicates:  22  - removed:  9
# Count negatives:  0
# Count useful:  22
# sleep_form_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv
#
#
#
# Client:  2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0
# Total count:  48
# Count with less 24hs:  48  - removed:  0
# Count without duplicates:  30  - removed:  18
# Count negatives:  0
# Count useful:  30
# sleep_form_2J22RukYnEbKTk7tiUVDBkorcyL5NKN6TrLe89ys.csv
#
#
#
# Client:  2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys
# Total count:  50
# Count with less 24hs:  40  - removed:  10
# Count without duplicates:  15  - removed:  25
# Count negatives:  0
# Count useful:  15
# sleep_form_7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA.csv
#
#
#
# Client:  7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA
# Total count:  15
# Count with less 24hs:  14  - removed:  1
# Count without duplicates:  13  - removed:  1
# Count negatives:  0
# Count useful:  13
# sleep_form_a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4.csv
#
#
#
# Client:  a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4
# Total count:  50
# Count with less 24hs:  27  - removed:  23
# Count without duplicates:  18  - removed:  9
# Count negatives:  0
# Count useful:  18
# sleep_form_ae4JJBZDycEcY8McJF3BxyvZ1619y03BNdCxzpZTc.csv
#
#
#
# Client:  ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc
# Total count:  22
# Count with less 24hs:  22  - removed:  0
# Count without duplicates:  18  - removed:  4
# Count negatives:  0
# Count useful:  18
# sleep_form_Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U.csv
#
#
#
# Client:  Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U
# Total count:  53
# Count with less 24hs:  45  - removed:  8
# Count without duplicates:  26  - removed:  19
# Count negatives:  0
# Count useful:  26
# sleep_form_CH8f0yZkZL13zWuE9ks1CkVJRVrrjsGdUXHrZ6YeA.csv
#
#
#
# Client:  CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA
# Total count:  66
# Count with less 24hs:  65  - removed:  1
# Count without duplicates:  28  - removed:  37
# Count negatives:  2
# Count useful:  26
# sleep_form_DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc.csv
#
#
#
# Client:  DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc
# Total count:  22
# Count with less 24hs:  22  - removed:  0
# Count without duplicates:  21  - removed:  1
# Count negatives:  0
# Count useful:  21
# sleep_form_DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA.csv
#
#
#
# Client:  DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA
# Total count:  6
# Count with less 24hs:  6  - removed:  0
# Count without duplicates:  3  - removed:  3
# Count negatives:  0
# Count useful:  3
# sleep_form_dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY.csv
#
#
#
# Client:  dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY
# Total count:  66
# Count with less 24hs:  63  - removed:  3
# Count without duplicates:  31  - removed:  32
# Count negatives:  0
# Count useful:  31
# sleep_form_HFvs2CohmhHteAaCzFasjzegGzxZKPhkrX23iI6Xo.csv
#
#
#
# Client:  HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo
# Total count:  49
# Count with less 24hs:  44  - removed:  5
# Count without duplicates:  24  - removed:  20
# Count negatives:  0
# Count useful:  24
# sleep_form_jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw.csv
#
#
#
# Client:  jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw
# Total count:  28
# Count with less 24hs:  27  - removed:  1
# Count without duplicates:  24  - removed:  3
# Count negatives:  0
# Count useful:  24
# sleep_form_JkYR7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I.csv
#
#
#
# Client:  JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I
# Total count:  52
# Count with less 24hs:  52  - removed:  0
# Count without duplicates:  30  - removed:  22
# Count negatives:  0
# Count useful:  30
# sleep_form_K4SLohfTN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8.csv
#
#
#
# Client:  K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8
# Total count:  42
# Count with less 24hs:  40  - removed:  2
# Count without duplicates:  23  - removed:  17
# Count negatives:  0
# Count useful:  23
# sleep_form_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv
#
#
#
# Client:  oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
# Total count:  50
# Count with less 24hs:  49  - removed:  1
# Count without duplicates:  38  - removed:  11
# Count negatives:  2
# Count useful:  36
# sleep_form_pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM.csv
#
#
#
# Client:  pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM
# Total count:  22
# Count with less 24hs:  20  - removed:  2
# Count without duplicates:  18  - removed:  2
# Count negatives:  0
# Count useful:  18
# sleep_form_PZCf1nfvhR6fk7sPNMYOgb8BAMmtQtfoRS83Suc.csv
#
#
#
# Client:  PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# Total count:  9
# Count with less 24hs:  8  - removed:  1
# Count without duplicates:  6  - removed:  2
# Count negatives:  0
# Count useful:  6
# sleep_form_QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXXcQ.csv
#
#
#
# Client:  QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ
# Total count:  28
# Count with less 24hs:  27  - removed:  1
# Count without duplicates:  22  - removed:  5
# Count negatives:  0
# Count useful:  22
# sleep_form_rIl2UK9bQtzpFdbJAdbBxEa5GbgrgC030yEaENLw.csv
#
#
#
# Client:  rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# Total count:  19
# Count with less 24hs:  15  - removed:  4
# Count without duplicates:  15  - removed:  0
# Count negatives:  0
# Count useful:  15
# sleep_form_RoBW3cDOO9wWRMPO2twQff83MPcOXn6gJa1DafreI.csv
#
#
#
# Client:  RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# Total count:  40
# Count with less 24hs:  39  - removed:  1
# Count without duplicates:  28  - removed:  11
# Count negatives:  0
# Count useful:  28
# sleep_form_SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4.csv
#
#
#
# Client:  SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4
# Total count:  20
# Count with less 24hs:  20  - removed:  0
# Count without duplicates:  19  - removed:  1
# Count negatives:  0
# Count useful:  19
# sleep_form_VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is.csv
#
#
#
# Client:  VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# Total count:  38
# Count with less 24hs:  32  - removed:  6
# Count without duplicates:  25  - removed:  7
# Count negatives:  0
# Count useful:  25
# sleep_form_Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw.csv
#
#
#
# Client:  Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# Total count:  24
# Count with less 24hs:  24  - removed:  0
# Count without duplicates:  16  - removed:  8
# Count negatives:  0
# Count useful:  16
# sleep_form_XCKRE0BWRHxfP1kZIihgtTjUjSp2GE8v5ZlhcIhVmA.csv
#
#
#
# Client:  XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# Total count:  35
# Count with less 24hs:  34  - removed:  1
# Count without duplicates:  26  - removed:  8
# Count negatives:  0
# Count useful:  26
# sleep_form_YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw.csv
#
#
#
# Client:  YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# Total count:  25
# Count with less 24hs:  23  - removed:  2
# Count without duplicates:  23  - removed:  0
# Count negatives:  0
# Count useful:  23
# sleep_form_ypklj8GJ15rOIH1lpKQtFJOuKVdvyCuBPqhY3aoM.csv
#
#
#
# Client:  ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# Total count:  1
# Count with less 24hs:  1  - removed:  0
# Count without duplicates:  1  - removed:  0
# Count negatives:  0
# Count useful:  1
# sleep_form_ZSsAZ0PqMCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv
#
#
#
# Client:  ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY
# Total count:  21
# Count with less 24hs:  20  - removed:  1
# Count without duplicates:  20  - removed:  0
# Count negatives:  1
# Count useful:  19
#
#
#
# Total: 965
# duplicated: 282
# >24: 74
# 0-24: 604 useful
# <=0: 5
# Useful: 604 useful
